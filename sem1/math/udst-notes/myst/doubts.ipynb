# %% [markdown]
# ---
# title: Doubts
# ---

# %% [markdown]
# > ![](attachment:image-8.png)
#
# I get $\cos \theta = -\frac{1}{2}$
#
# Should take $\cos \theta = -\frac{1}{2}$ or $\cos \theta = \frac{1}{2}$
# to find the reference angle

# %% [markdown]
# ![image.png](attachment:image.png)
# How do i make this better?
